# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
plt.scatter(df['cgpa'],df['resume_score'],c=df['placed'])

# %%
x = df.iloc[:,0:2].values
y = df.iloc[:,-1].values

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
# Out:
# c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
model = Sequential()

model.add(Dense(3,activation='relu',input_dim = 2))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 3)              │             9 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (52.00 B)
#  Trainable params: 13 (52.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.get_weights()
# Out:
# [array([[-0.35740733, -0.74209094,  0.37916505],
#         [-0.946676  , -0.41451132, -0.05917561]], dtype=float32),
#  array([0., 0., 0.], dtype=float32),
#  array([[-0.15650952],
#         [-0.17250597],
#         [-0.6029002 ]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
initial_weights = model.get_weights()

# %%
initial_weights[0] = np.zeros(model.get_weights()[0].shape)
initial_weights[1] = np.zeros(model.get_weights()[1].shape)
initial_weights[2] = np.zeros(model.get_weights()[2].shape)
initial_weights[3] = np.zeros(model.get_weights()[3].shape)

# %%
model.set_weights(initial_weights)

# %%
model.get_weights()
# Out:
# [array([[0., 0., 0.],
#         [0., 0., 0.]], dtype=float32),
#  array([0., 0., 0.], dtype=float32),
#  array([[0.],
#         [0.],
#         [0.]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history = model.fit(x,y,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4125 - loss: 0.6932 - val_accuracy: 0.4500 - val_loss: 0.6932
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6932
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6932
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6933
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6933
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6933
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6934
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6935
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6935
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6935
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6935
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6935
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6935
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6936
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5125 - loss: 0.6931 - val_accuracy: 0.4500 - val_loss: 0.6936
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6936
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6936
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6936
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6937
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6937
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6937
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6937
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6937
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6937
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6938
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6939
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6939
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6939
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6939
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6939
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6939
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6939
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6939
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6940
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6940
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6940
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6940
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6940
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6940
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6941
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6941
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6941
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6941
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6942
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6942
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6942
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6943
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4500 - val_loss: 0.6942
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6943
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6943
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6943
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6944
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6944
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6944
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6944
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6944
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6944
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6944
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6945
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6945
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6945
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6946
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6946
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6946
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6946
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6946
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6946
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6946
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5125 - loss: 0.6929 - val_accuracy: 0.4500 - val_loss: 0.6946

# %%
model.get_weights()
# Out:
# [array([[0., 0., 0.],
#         [0., 0., 0.]], dtype=float32),
#  array([0., 0., 0.], dtype=float32),
#  array([[0.],
#         [0.],
#         [0.]], dtype=float32),
#  array([0.02792113], dtype=float32)]

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x,y.astype('int'),clf=model,legend=2)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 7s 750us/step
# <Axes: >
