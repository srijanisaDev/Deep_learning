# %%
docs = ['go india',
		'india india',
		'hip hip hurray',
		'jeetega bhai jeetega india jeetega',
		'bharat mata ki jai',
		'kohli kohli',
		'sachin sachin',
		'dhoni dhoni',
		'modi ji ki jai',
		'inquilab zindabad']

# %%
import tensorflow
from tensorflow import keras

# %%
from  tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)
# Out:
# 17

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[9, 1],
#  [1, 1],
#  [3, 3, 10],
#  [2, 11, 2, 1, 2],
#  [12, 13, 4, 5],
#  [6, 6],
#  [7, 7],
#  [8, 8],
#  [14, 15, 4, 5],
#  [16, 17]]

# %%
from keras.utils import pad_sequences
sequences = pad_sequences(sequences,padding='post')
sequences
# Out:
# array([[ 9,  1,  0,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 3,  3, 10,  0,  0],
#        [ 2, 11,  2,  1,  2],
#        [12, 13,  4,  5,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [14, 15,  4,  5,  0],
#        [16, 17,  0,  0,  0]], dtype=int32)

# %%
from keras import Sequential

# %%
model = Sequential()
model.add(Embedding(17,output_dim=2,input_length=5))

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam','accuracy')

# %%
pred = model.predict(sequences)
print(pred)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 pred = model.predict(sequences)
#       2 print(pred)
#
# File c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sequential_2_1/embedding_1_1/GatherV2 defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\asyncio\base_events.py", line 679, in run_forever
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\asyncio\base_events.py", line 2027, in _run_once
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\asyncio\events.py", line 89, in _run
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3123, in run_cell
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3178, in _run_cell
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3400, in run_cell_async
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3641, in run_ast_nodes
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3701, in run_code
#
#   File "C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_22728\2269839758.py", line 1, in <module>
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 588, in predict
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 282, in one_step_on_data_distributed
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 125, in wrapper
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 271, in one_step_on_data
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 110, in predict_step
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\layers\layer.py", line 953, in __call__
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\ops\operation.py", line 59, in __call__
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\models\sequential.py", line 220, in call
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\models\functional.py", line 183, in call
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\ops\function.py", line 206, in _run_through_graph
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\models\functional.py", line 647, in call
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\layers\layer.py", line 953, in __call__
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\ops\operation.py", line 59, in __call__
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\layers\core\embedding.py", line 166, in call
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\ops\numpy.py", line 6275, in take
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\backend\tensorflow\numpy.py", line 2619, in take
#
# indices[9,1] = 17 is not in [0, 17)
# 	 [[{{node sequential_2_1/embedding_1_1/GatherV2}}]] [Op:__inference_one_step_on_data_distributed_392]

# %%
from keras.datasets import imdb
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data()
# Out:
# c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\numpy\lib\_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)

# %%
X_train = pad_sequences(X_train,padding='post',maxlen=50)
X_test = pad_sequences(X_test,padding='post',maxlen=50)

# %%
model = Sequential()

model.add(Embedding(10000, 2, input_length=50))

model.add(SimpleRNN(32, return_sequences=False))

model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
import numpy as np

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# history = model.fit(
#     X_train, y_train,
#     epochs=5,
#     validation_data=(X_test, y_test)
# )
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 history = model.fit(
#       2     X_train, y_train,
#       3     epochs=5,
#       4     validation_data=(X_test, y_test)
#       5 )
#
# File c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sequential_4_1/embedding_3_1/GatherV2 defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\asyncio\base_events.py", line 679, in run_forever
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\asyncio\base_events.py", line 2027, in _run_once
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\asyncio\events.py", line 89, in _run
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3123, in run_cell
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3178, in _run_cell
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3400, in run_cell_async
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3641, in run_ast_nodes
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3701, in run_code
#
#   File "C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_22728\3488061723.py", line 1, in <module>
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 399, in fit
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 241, in function
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 154, in multi_step_on_iterator
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 125, in wrapper
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 134, in one_step_on_data
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 59, in train_step
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\layers\layer.py", line 953, in __call__
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\ops\operation.py", line 59, in __call__
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\models\sequential.py", line 220, in call
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\models\functional.py", line 183, in call
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\ops\function.py", line 206, in _run_through_graph
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\models\functional.py", line 647, in call
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\layers\layer.py", line 953, in __call__
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\ops\operation.py", line 59, in __call__
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\layers\core\embedding.py", line 166, in call
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\ops\numpy.py", line 6275, in take
#
#   File "c:\Users\KIIT0001\Desktop\Deep_learning\venv\Lib\site-packages\keras\src\backend\tensorflow\numpy.py", line 2619, in take
#
# indices[0,3] = 14922 is not in [0, 10000)
# 	 [[{{node sequential_4_1/embedding_3_1/GatherV2}}]] [Op:__inference_multi_step_on_iterator_8946]
